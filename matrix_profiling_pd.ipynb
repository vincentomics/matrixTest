# %%
import pandas as pd
import numpy as np
import time
import os

def generate_count_df(rows, cols, min_val=0, max_val=100, seed=42):
    """Generate a DataFrame of random integer counts with specified dimensions"""
    rng = np.random.default_rng(seed)
    data = rng.integers(min_val, max_val + 1, size=(rows, cols))
    return pd.DataFrame(data)

def write_df_to_txt(df, filename="temp_df.txt"):
    df.to_csv(filename, sep="\t", header=False, index=False)

def read_df_from_txt(filename="temp_df.txt"):
    return pd.read_csv(filename, sep="\t", header=None)

def profile_operations(df_row, df_col, label="DataFrame", n_iter=1000, filename_prefix="temp_df"):
    print(f"--- {label} Test ({df_row.shape[0]} x {df_row.shape[1]}) ---")
    print("DataFrame shapes:")
    print(f"- row-oriented: {df_row.shape}")
    print(f"- col-oriented: {df_col.shape}")

    operations = {
        f"row-oriented sum": lambda: df_row.sum(axis=1),
        f"col-oriented sum": lambda: df_col.sum(axis=0),
        f"row-oriented mean": lambda: df_row.mean(axis=1),
        f"col-oriented mean": lambda: df_col.mean(axis=0),
        f"row-oriented std": lambda: df_row.std(axis=1),
        f"col-oriented std": lambda: df_col.std(axis=0),
        f"row-oriented transpose": lambda: df_row.T,
        f"col-oriented transpose": lambda: df_col.T,
        f"row-oriented reshape (flat -> 50)": lambda: pd.DataFrame(df_row.values.reshape(-1, 50)),
        f"col-oriented reshape (flat -> 50)": lambda: pd.DataFrame(df_col.values.reshape(-1, 50)),
        f"row-oriented write to txt": lambda: write_df_to_txt(df_row, filename=f"{filename_prefix}_row.txt"),
        f"col-oriented write to txt": lambda: write_df_to_txt(df_col, filename=f"{filename_prefix}_col.txt"),
        f"row-oriented read from txt": lambda: read_df_from_txt(filename=f"{filename_prefix}_row.txt"),
        f"col-oriented read from txt": lambda: read_df_from_txt(filename=f"{filename_prefix}_col.txt")
    }

    print("\n=== Multiple Operations Profiling ===")
    for op_name, operation in operations.items():
        times = []
        n_runs = n_iter if "read" not in op_name and "write" not in op_name else max(1, int(n_iter / 10))
        for _ in range(n_runs):
            start_time = time.perf_counter()
            operation()
            end_time = time.perf_counter()
            times.append(end_time - start_time)
        mean_time = np.mean(times)
        std_time = np.std(times)

        print(f"{op_name:35s}: {mean_time:.6f} ± {std_time:.6f} seconds (mean ± std over {n_runs} runs)")

    # Clean up
    for suffix in ["row", "col"]:
        path = f"{filename_prefix}_{suffix}.txt"
        if os.path.exists(path):
            os.remove(path)

def run_all_profiles():
    sizes = {
        "Tiny": (100, 100, 100000),
        "Small": (1_000, 1_000, 10000),
        "Medium": (10_000, 1_000, 1000),
        "Large": (100_000, 1_000, 100),
    }
    for label, (n_row, n_col, n_iter) in sizes.items():
        df_row = generate_count_df(n_row, n_col)
        df_col = generate_count_df(n_col, n_row)
        profile_operations(df_row, df_col, label=label, filename_prefix=f"temp_{label.lower()}_df", n_iter=n_iter)
        print("\n\n")

time_start = time.perf_counter()
run_all_profiles()
time_end = time.perf_counter()
print(f"\n=== Test time taken: {time_end - time_start:.2f} seconds ===\n")
# Out:
# --- Tiny Test (100 x 100) ---
# DataFrame shapes:
# - row-oriented: (100, 100)
# - col-oriented: (100, 100)
#
# === Multiple Operations Profiling ===
# row-oriented sum                   : 0.000252 ± 0.000022 seconds (mean ± std over 100000 runs)
# col-oriented sum                   : 0.000126 ± 0.000016 seconds (mean ± std over 100000 runs)
# row-oriented mean                  : 0.000288 ± 0.000017 seconds (mean ± std over 100000 runs)
# col-oriented mean                  : 0.000159 ± 0.000010 seconds (mean ± std over 100000 runs)
# row-oriented std                   : 0.000339 ± 0.000014 seconds (mean ± std over 100000 runs)
# col-oriented std                   : 0.000204 ± 0.000013 seconds (mean ± std over 100000 runs)
# row-oriented transpose             : 0.000063 ± 0.000012 seconds (mean ± std over 100000 runs)
# col-oriented transpose             : 0.000063 ± 0.000004 seconds (mean ± std over 100000 runs)
# row-oriented reshape (flat -> 50)  : 0.000015 ± 0.000003 seconds (mean ± std over 100000 runs)
# col-oriented reshape (flat -> 50)  : 0.000016 ± 0.000003 seconds (mean ± std over 100000 runs)
# row-oriented write to txt          : 0.002179 ± 0.000583 seconds (mean ± std over 10000 runs)
# col-oriented write to txt          : 0.002175 ± 0.000079 seconds (mean ± std over 10000 runs)
# row-oriented read from txt         : 0.002252 ± 0.000389 seconds (mean ± std over 10000 runs)
# col-oriented read from txt         : 0.002242 ± 0.000060 seconds (mean ± std over 10000 runs)
#
#
#
# --- Small Test (1000 x 1000) ---
# DataFrame shapes:
# - row-oriented: (1000, 1000)
# - col-oriented: (1000, 1000)
#
# === Multiple Operations Profiling ===
# row-oriented sum                   : 0.000782 ± 0.000031 seconds (mean ± std over 10000 runs)
# col-oriented sum                   : 0.000592 ± 0.000031 seconds (mean ± std over 10000 runs)
# row-oriented mean                  : 0.001435 ± 0.000061 seconds (mean ± std over 10000 runs)
# col-oriented mean                  : 0.001170 ± 0.000074 seconds (mean ± std over 10000 runs)
# row-oriented std                   : 0.009886 ± 0.000767 seconds (mean ± std over 10000 runs)
# col-oriented std                   : 0.008813 ± 0.000271 seconds (mean ± std over 10000 runs)
# row-oriented transpose             : 0.000137 ± 0.000008 seconds (mean ± std over 10000 runs)
# col-oriented transpose             : 0.000135 ± 0.000007 seconds (mean ± std over 10000 runs)
# row-oriented reshape (flat -> 50)  : 0.000016 ± 0.000005 seconds (mean ± std over 10000 runs)
# col-oriented reshape (flat -> 50)  : 0.000016 ± 0.000007 seconds (mean ± std over 10000 runs)
# row-oriented write to txt          : 0.183429 ± 0.002131 seconds (mean ± std over 1000 runs)
# col-oriented write to txt          : 0.181398 ± 0.001686 seconds (mean ± std over 1000 runs)
# row-oriented read from txt         : 0.072276 ± 0.002816 seconds (mean ± std over 1000 runs)
# col-oriented read from txt         : 0.072587 ± 0.002904 seconds (mean ± std over 1000 runs)
#
#
#
# --- Medium Test (10000 x 1000) ---
# DataFrame shapes:
# - row-oriented: (10000, 1000)
# - col-oriented: (1000, 10000)
#
# === Multiple Operations Profiling ===
# row-oriented sum                   : 0.007656 ± 0.000175 seconds (mean ± std over 1000 runs)
# col-oriented sum                   : 0.007912 ± 0.000172 seconds (mean ± std over 1000 runs)
# row-oriented mean                  : 0.012577 ± 0.000256 seconds (mean ± std over 1000 runs)
# col-oriented mean                  : 0.012245 ± 0.000226 seconds (mean ± std over 1000 runs)
# row-oriented std                   : 0.105178 ± 0.001447 seconds (mean ± std over 1000 runs)
# col-oriented std                   : 0.101879 ± 0.000923 seconds (mean ± std over 1000 runs)
# row-oriented transpose             : 0.000150 ± 0.000016 seconds (mean ± std over 1000 runs)
# col-oriented transpose             : 0.000768 ± 0.000036 seconds (mean ± std over 1000 runs)
# row-oriented reshape (flat -> 50)  : 0.000016 ± 0.000002 seconds (mean ± std over 1000 runs)
# col-oriented reshape (flat -> 50)  : 0.000016 ± 0.000001 seconds (mean ± std over 1000 runs)
# row-oriented write to txt          : 1.814671 ± 0.017823 seconds (mean ± std over 100 runs)
# col-oriented write to txt          : 2.781901 ± 0.014204 seconds (mean ± std over 100 runs)
# row-oriented read from txt         : 0.551156 ± 0.006585 seconds (mean ± std over 100 runs)
# col-oriented read from txt         : 1.383608 ± 0.013076 seconds (mean ± std over 100 runs)
#
#
#
# --- Large Test (100000 x 1000) ---
# DataFrame shapes:
# - row-oriented: (100000, 1000)
# - col-oriented: (1000, 100000)
#
# === Multiple Operations Profiling ===
# row-oriented sum                   : 0.078226 ± 0.000546 seconds (mean ± std over 100 runs)
# col-oriented sum                   : 0.098387 ± 0.000847 seconds (mean ± std over 100 runs)
# row-oriented mean                  : 0.123115 ± 0.001743 seconds (mean ± std over 100 runs)
# col-oriented mean                  : 0.132051 ± 0.001993 seconds (mean ± std over 100 runs)
# row-oriented std                   : 1.064153 ± 0.003022 seconds (mean ± std over 100 runs)
# col-oriented std                   : 1.085659 ± 0.003442 seconds (mean ± std over 100 runs)
# row-oriented transpose             : 0.000137 ± 0.000016 seconds (mean ± std over 100 runs)
# col-oriented transpose             : 0.006858 ± 0.000163 seconds (mean ± std over 100 runs)
# row-oriented reshape (flat -> 50)  : 0.000017 ± 0.000006 seconds (mean ± std over 100 runs)
# col-oriented reshape (flat -> 50)  : 0.000017 ± 0.000002 seconds (mean ± std over 100 runs)
# row-oriented write to txt          : 18.154100 ± 0.095540 seconds (mean ± std over 10 runs)
# col-oriented write to txt          : 139.034594 ± 0.283293 seconds (mean ± std over 10 runs)
# row-oriented read from txt         : 5.049500 ± 0.124253 seconds (mean ± std over 10 runs)
# col-oriented read from txt         : 75.839842 ± 0.122664 seconds (mean ± std over 10 runs)
#
#
#
#
# === Test time taken: 4523.61 seconds ===

# %% [markdown]
# # legacy code

# %%
n_col = 10000
n_row = 10000
data_rows = pd.DataFrame(np.random.rand(n_col, n_row))

start_time = time.time()
# Compute std for each feature (row-wise)
std_rows = data_rows.std(axis=1)
print(std_rows.shape)
elapsed_rows = time.time() - start_time

print(f"Case 1 (features as rows): {elapsed_rows:.4f} seconds")
